# %% [markdown]
# # Assignment kmeans clustering EastWestAirlines

# %%
import pandas as pd
import matplotlib.pylab as plt
from sklearn.cluster import KMeans
import numpy as np

# %%
X = np.random.uniform(0,1,1000)
Y = np.random.uniform(0,1,1000)
X
# Out:
# array([0.14055719, 0.43641775, 0.72720097, 0.61163302, 0.5128573 ,
#        0.28894922, 0.54864713, 0.69686475, 0.80111995, 0.80798367,
#        0.51412311, 0.26337031, 0.83518994, 0.29848037, 0.15922167,
#        0.20896823, 0.69462632, 0.54332701, 0.77677661, 0.05130563,
#        0.98454368, 0.8032402 , 0.14221842, 0.5773671 , 0.85927177,
#        0.4840242 , 0.82412745, 0.43854789, 0.14504965, 0.68170601,
#        0.99037268, 0.99282459, 0.46425058, 0.09196812, 0.87249463,
#        0.60910953, 0.31478367, 0.24688456, 0.50913803, 0.42499974,
#        0.05018212, 0.99508103, 0.72357428, 0.98606396, 0.22647864,
#        0.93585086, 0.07285147, 0.73895061, 0.68724031, 0.64335119,
#        0.1467893 , 0.20365522, 0.32466695, 0.12507499, 0.6040924 ,
#        0.79720148, 0.56148325, 0.79530381, 0.22141861, 0.45578696,
#        0.7808399 , 0.50671182, 0.60852195, 0.01946752, 0.8553988 ,
#        0.30639634, 0.30333437, 0.36115404, 0.56413341, 0.66794363,
# ...

# %%
df_xy =pd.DataFrame(columns=["X","Y"])
df_xy
df_xy.X = X
df_xy.Y = Y
df_xy
df_xy.plot(x="X",y = "Y",kind="scatter")
model1 = KMeans(n_clusters=5).fit(df_xy)

# %%
df_xy.plot(x="X",y = "Y",c=model1.labels_,kind="scatter",s=50,cmap=plt.cm.coolwarm_r)
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
#readng sheets from excel
eastWest_data_xl = pd.ExcelFile("D:/datascience Excelr/class docs and assignments/Assignments/In progress/Clustering/EastWestAirlines/EastWestAirlines.xlsx")
eastWest_data_xl.sheet_names
# Out:
# ['Description', 'data']

# %%
eastWest_data=df1 = eastWest_data_xl.parse('data')
eastWest_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
ew_reset=eastWest_data.set_index('ID#')

# %%
ew_reset
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# ...

# %%
def norm_func(i):
    x = (i-i.min()) / (i.max() - i.min())
    return (x)

# %%
df_norm = norm_func(eastWest_data.iloc[:,1:])

# %%
df_norm.head(10)  # Top 10 rows
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
# 5  0.009631         0.0       0.00        0.0        0.0     0.000000
# 6  0.049808         0.0       0.50        0.0        0.0     0.104223
# 7  0.012233         0.0       0.00        0.0        0.0     0.019910
# 8  0.259850         0.0       0.50        0.5        0.0     0.006648
# 9  0.061507         0.0       0.50        0.0        0.0     0.107803
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0     0.011628           0.000000         0.000000           0.843742     0.0
# ...

# %%
from sklearn.cluster import KMeans
fig = plt.figure(figsize=(10, 8))
WCSS = []
for i in range(1, 11):
    clf = KMeans(n_clusters=i)
    clf.fit(df_norm)
    WCSS.append(clf.inertia_) # inertia is another name for WCSS
plt.plot(range(1, 11), WCSS)
plt.title('The Elbow Method')
plt.ylabel('WCSS')
plt.xlabel('Number of Clusters')
plt.show()

# %%
clf = KMeans(n_clusters=5)
y_kmeans = clf.fit_predict(df_norm)

# %%
y_kmeans
#clf.cluster_centers_
clf.labels_
# Out:
# array([1, 1, 1, ..., 0, 4, 4])

# %%
y_kmeans
# Out:
# array([1, 1, 1, ..., 0, 4, 4])

# %%
clf.cluster_centers_
# Out:
# array([[ 6.35352962e-02,  1.77912301e-02,  7.28960396e-01,
#          6.18811881e-04,  6.49752475e-03,  1.72970238e-01,
#          2.34903868e-01,  2.31602349e-02,  4.04212591e-02,
#          5.86139300e-01,  1.00000000e+00],
#        [ 2.92823328e-02,  8.06451613e-03,  3.05299539e-02,
#          9.79262673e-03,  2.88018433e-04,  1.31485480e-02,
#          8.03906334e-02,  7.91232441e-03,  1.37379358e-02,
#          6.71078504e-01,  1.11022302e-15],
#        [ 4.89953609e-02,  2.60542873e-02,  3.90044577e-02,
#          1.63447251e-02,  2.22882615e-03,  3.35642727e-02,
#          1.21825219e-01,  3.34267751e-02,  5.94073285e-02,
#          5.22892182e-01,  1.00000000e+00],
#        [ 6.93891884e-02,  6.59020789e-03,  6.46035599e-01,
#          8.09061489e-04,  5.66343042e-03,  1.19022293e-01,
#          2.00383834e-01,  7.27197078e-03,  1.18458814e-02,
#          5.32620376e-01, -4.44089210e-16],
#        [ 1.94137515e-02,  8.44382696e-03,  1.76841085e-02,
# ...

# %%
clf.inertia_
# Out:
# 348.94332172541357

# %%
md=pd.Series(y_kmeans)  # converting numpy array into pandas series object 
eastWest_data['clust']=md # creating a  new column and assigning it to new column 
eastWest_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
eastWest_data.iloc[:,1:7].groupby(eastWest_data.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0      108317.387376  198.336634   3.915842   1.001238   1.025990
# 1       49921.633641   89.903226   1.122120   1.019585   1.001152
# 2       83529.153046  290.453195   1.156018   1.032689   1.008915
# 3      118297.325243   73.467638   3.584142   1.001618   1.022654
# 4       33097.301357   94.131783   1.070736   1.016473   1.006783
#
#         Bonus_miles
# clust
# 0      45609.657178
# 1       3467.074885
# 2       8850.395245
# 3      31384.393204
# 4       3244.520349

# %%
plt.style.use(['classic']) 
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
eastWest_data.plot(x="Balance",y ="Qual_miles",c=clf.labels_,kind="scatter",s=30 ,cmap=plt.cm.coolwarm) 
plt.title('Clusters using KMeans')
# Out:
# Text(0.5, 1.0, 'Clusters using KMeans')

# %%
WCSS
# Out:
# [1830.7932128584112,
#  823.6756984125205,
#  625.1684881570719,
#  436.71719004195575,
#  348.9433217254136,
#  319.01115138210804,
#  290.46960323494733,
#  263.2142998913929,
#  243.92443618938395,
#  226.110072051378]
